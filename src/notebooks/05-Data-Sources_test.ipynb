# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Copyright by Pierian Data Inc.</em></center>
# <center><em>For more information, visit us at <a href='http://www.pieriandata.com'>www.pieriandata.com</a></em></center>

# %% [markdown]
# ### IMPORTANT NOTE: Your internet service provider or network admin or firewall may block you from directly reading information from outside sources. Please keep this in mind if you get errors. Also note, APIs change often, make sure to do your best independent research to explore current best options, as the code seen here may change.

# %% [markdown]
# ## Pandas DataReader
#
# Make sure to check the latest examples and notification of API changes here:
# https://pandas-datareader.readthedocs.io/en/latest/remote_data.html#remote-data-wb

# %% [markdown]
# #### General Stock Data from Yahoo (not official API)

# %%
import pandas_datareader.data as web
from datetime import datetime, date
# %matplotlib inline

# %%
import datetime as dt
import yfinance as yf

company = 'IAG.MC'

# Define a start date and End Date
start = dt.datetime(2025,1,1)
end =  dt.datetime(2025,9,3)

# Read Stock Price Data 
data = yf.download(company, start , end)

data.tail(10)
# Out:
# /tmp/ipykernel_5645/1191909545.py:11: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(company, start , end)
# [*********************100%***********************]  1 of 1 completed
# Price       Close   High    Low   Open   Volume
# Ticker     IAG.MC IAG.MC IAG.MC IAG.MC   IAG.MC
# Date
# 2025-08-20  4.481  4.552  4.461  4.532  6635039
# 2025-08-21  4.464  4.493  4.412  4.471  7054427
# 2025-08-22  4.560  4.576  4.444  4.444  9275012
# 2025-08-25  4.513  4.550  4.505  4.540  3191157
# 2025-08-26  4.545  4.575  4.484  4.524  8146898
# 2025-08-27  4.466  4.572  4.438  4.550  6597452
# 2025-08-28  4.490  4.521  4.475  4.485  3401690
# 2025-08-29  4.412  4.484  4.383  4.480  6297916
# 2025-09-01  4.552  4.552  4.402  4.409  6113636
# 2025-09-02  4.373  4.540  4.333  4.525  8389380

# %%
data = yf.Ticker(company)

# %%
info = data.info

# rentabilidad por dividendo
dividend_yield = info.get('dividendYield')  
# P/E trailing (últimos 12 meses)
pe_trailing = info.get('trailingPE')  
# P/B ratio
pb = info.get('priceToBook')

# %%
pe_trailing
# Out:
# 6.8307695

# %%
dividendYield
trailingPE
forwardPE
volume
# rentabilidad por dividendo
dividend_yield = info.get('dividendYield')  
# P/E trailing (últimos 12 meses)
pe_trailing = info.get('trailingPE')  

# P/E trailing (últimos 12 meses)
pe_foward = info.get('forwardPE') 
# P/B ratio
pb = info.get('priceToBook')

volume = info.get('volume')

'beta': 1.96,
 'trailingPE': 6.8307695,
 'forwardPE': 3.762712,
 'volume': 5844616,
 'regularMarketVolume': 5844616,
 'averageVolume': 9399310,
 'averageVolume10days': 7949967,
 'averageDailyVolume10Day': 7949967,
 'bid': 4.448,
 'ask': 4.45,
 'bidSize': 0,
 'askSize': 0,
 'marketCap': 20515598336,
# Out:
#   Cell In[10], line 3
#     'beta': 1.96,
#     ^
# IndentationError: unexpected indent

# %%
data.get_info()
# Out:
# {'address1': 'Waterside (HAA2)',
#  'address2': 'PO Box 365',
#  'city': 'Harmondsworth',
#  'zip': 'UB7 0GB',
#  'country': 'United Kingdom',
#  'website': 'https://www.iairgroup.com',
#  'industry': 'Airlines',
#  'industryKey': 'airlines',
#  'industryDisp': 'Airlines',
#  'sector': 'Industrials',
#  'sectorKey': 'industrials',
#  'sectorDisp': 'Industrials',
# ...

# %%
data.analyst_price_targets
# Out:
# {'current': 4.475, 'high': 5.5, 'low': 4.5, 'mean': 5.06667, 'median': 5.2}

# %%
data
# Out:
# yfinance.Ticker object <IAG.MC>

# %%
data.calendar
# Out:
# {'Ex-Dividend Date': datetime.date(2025, 6, 26),
#  'Earnings Date': [datetime.date(2025, 8, 1)],
#  'Earnings High': 0.29,
#  'Earnings Low': 0.27182,
#  'Earnings Average': 0.28091,
#  'Revenue High': 9620847000,
#  'Revenue Low': 9337554740,
#  'Revenue Average': 9465467250}

# %%
dat.analyst_price_targets
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dat.analyst_price_targets
#
# NameError: name 'dat' is not defined

# %%
data.quarterly_income_stmt
# Out:
#                                                       2025-06-30  \
# Tax Effect Of Unusual Items                        -3.776908e+07
# Tax Rate For Calcs                                  2.534840e-01
# Normalized EBITDA                                   1.868000e+09
# Total Unusual Items                                -1.490000e+08
# Total Unusual Items Excluding Goodwill             -1.490000e+08
# Net Income From Continuing Operation Net Minori...  1.125000e+09
# Reconciled Cost Of Revenue                          6.646000e+09
# EBITDA                                              1.719000e+09
# EBIT                                                1.719000e+09
# Net Interest Income                                -1.210000e+08
# Interest Expense                                    2.120000e+08
# Interest Income                                     7.000000e+07
# Normalized Income                                   1.236231e+09
# ...

# %%
data.history(period='1mo')
# Out:
#                             Open   High    Low  Close    Volume  Dividends  \
# Date
# 2025-08-04 00:00:00+02:00  4.342  4.404  4.303  4.329   7287334        0.0
# 2025-08-05 00:00:00+02:00  4.360  4.407  4.325  4.380   8890357        0.0
# 2025-08-06 00:00:00+02:00  4.388  4.388  4.272  4.293  10093607        0.0
# 2025-08-07 00:00:00+02:00  4.303  4.350  4.243  4.302   9299030        0.0
# 2025-08-08 00:00:00+02:00  4.320  4.325  4.261  4.303   5005532        0.0
# 2025-08-11 00:00:00+02:00  4.312  4.380  4.279  4.319   6380428        0.0
# 2025-08-12 00:00:00+02:00  4.340  4.472  4.307  4.460  13107717        0.0
# 2025-08-13 00:00:00+02:00  4.487  4.520  4.442  4.455   9410137        0.0
# 2025-08-14 00:00:00+02:00  4.472  4.520  4.443  4.460   7036551        0.0
# 2025-08-15 00:00:00+02:00  4.492  4.492  4.426  4.485   6915042        0.0
# 2025-08-18 00:00:00+02:00  4.484  4.524  4.461  4.520   5748437        0.0
# ...

# %%
dat = yf.Ticker("MSFT")
dat.info
dat.calendar
dat.analyst_price_targets
dat.quarterly_income_stmt
dat.history(period='1mo')
dat.option_chain(dat.options[0]).calls
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0   MSFT250905C00260000 2025-09-02 13:40:37+00:00   260.0     242.35  244.05
# 1   MSFT250905C00355000 2025-08-15 19:50:00+00:00   355.0     167.60  149.10
# 2   MSFT250905C00365000 2025-08-28 17:08:17+00:00   365.0     143.41  139.10
# 3   MSFT250905C00380000 2025-09-02 13:46:39+00:00   380.0     123.75  124.10
# 4   MSFT250905C00385000 2025-08-28 19:48:54+00:00   385.0     125.22  119.10
# ..                  ...                       ...     ...        ...     ...
# 75  MSFT250905C00630000 2025-08-14 17:06:19+00:00   630.0       0.03    0.00
# 76  MSFT250905C00635000 2025-08-12 16:51:28+00:00   635.0       0.04    0.00
# 77  MSFT250905C00640000 2025-08-08 16:52:08+00:00   640.0       0.01    0.00
# 78  MSFT250905C00645000 2025-08-04 17:29:20+00:00   645.0       0.04    0.00
# 79  MSFT250905C00650000 2025-09-02 13:30:00+00:00   650.0       0.01    0.00
#
# ...

# %%
# Creamos un objeto Market para el mercado europeo
EUROPE = yf.Market("EUROPE")

# Accedemos al estado del mercado (por ejemplo, si está abierto o cerrado)
print("Estado:", EUROPE.status)

# Obtenemos un resumen general del mercado
print("Resumen del mercado:", EUROPE.summary)
# Out:
# EUROPE: Failed to update market status
# Estado: {'id': 'us', 'name': 'U.S. markets', 'status': 'closed', 'yfit_market_id': 'us_market', 'close': '2025-09-03T20:00:00Z', 'message': 'U.S. markets closed', 'open': '2025-09-03T13:30:00Z', 'yfit_market_status': 'YFT_MARKET_CLOSED', 'timezone': {'dst': 'true', 'gmtoffset': '-14400', 'short': 'EDT', '$text': 'America/New_York'}}
# ...

# %%
import yfinance as yf

# Ejemplo: Banco Santander (ticker: SAN.MC)
santander = yf.Ticker("FER.MC")

# Obtener histórico diario del último año
hist = santander.history(period="1y")

print(hist.head())
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2024-09-03 00:00:00+02:00  37.133978  37.290744  36.663676  36.840038
# 2024-09-04 00:00:00+02:00  36.408934  36.781254  36.271764  36.683273
# 2024-09-05 00:00:00+02:00  36.604892  37.192763  36.506910  36.800850
# 2024-09-06 00:00:00+02:00  36.761657  37.271148  36.761657  36.820446
# 2024-09-09 00:00:00+02:00  37.016401  37.310341  36.918424  37.310341
#
#                             Volume  Dividends  Stock Splits
# Date
# 2024-09-03 00:00:00+02:00   709063        0.0           0.0
# 2024-09-04 00:00:00+02:00   460709        0.0           0.0
# 2024-09-05 00:00:00+02:00  5602570        0.0           0.0
# 2024-09-06 00:00:00+02:00   532327        0.0           0.0
# 2024-09-09 00:00:00+02:00   377379        0.0           0.0

# %%
ticker = '^IBEX' # You can study whatever ticker you want from the IBEX35 stock market. 
year = '2024'

# %%
stock_index = yf.download(ticker, progress=False)
stock_index.head(10)
# Out:
# C:\Users\rafa_\AppData\Local\Temp\ipykernel_1420\1097428426.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stock_index = yf.download(ticker, progress=False)
# Price              Close          High           Low          Open     Volume
# Ticker             ^IBEX         ^IBEX         ^IBEX         ^IBEX      ^IBEX
# Date
# 2025-08-04  14386.099609  14386.099609  14165.000000  14179.599609   88452700
# 2025-08-05  14407.500000  14450.299805  14275.700195  14438.500000   88499100
# 2025-08-06  14536.599609  14536.599609  14398.299805  14460.299805   95482200
# 2025-08-07  14690.900391  14690.900391  14586.500000  14589.500000  102037000
# 2025-08-08  14824.900391  14855.599609  14703.799805  14717.500000   95127000
# 2025-08-11  14855.900391  14881.599609  14730.500000  14865.500000   83418100
# 2025-08-12  14859.000000  14948.500000  14843.000000  14903.000000  102249100
# ...

# %%
data = yf.download("AAPL", start="2025-07-01", end=dt.datetime.today().strftime('%Y-%m-%d'))
# Out:
# C:\Users\rafa_\AppData\Local\Temp\ipykernel_9492\1787417814.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("AAPL", start="2025-07-01", end=dt.datetime.today().strftime('%Y-%m-%d'))
# [*********************100%***********************]  1 of 1 completed

# %%
aapl_df = web.DataReader('AAPL', 'yahoo', start=datetime(2025, 1, 1), end=datetime(2025, 7, 31))
# Out:
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 aapl_df = web.DataReader('AAPL', 'yahoo', start=datetime(2025, 1, 1), end=datetime(2025, 7, 31))
#
# File D:\Users\rafa_\pycharm-project-datos\venv-repos-data\Python-for-Finance-and-Algorithmic-Trading-with-QuantConnect\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File D:\Users\rafa_\pycharm-project-datos\venv-repos-data\Python-for-Finance-and-Algorithmic-Trading-with-QuantConnect\lib\site-packages\pandas_datareader\data.py:379, in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     367     raise NotImplementedError(msg)
#     369 if data_source == "yahoo":
# ...

# %%
# https://www.alphavantage.co/
api_key= 'ZQQPPSYZLH811CS9'
aapl_df = web.DataReader("AAPL", "av-daily", start=datetime(2023, 1, 1), end=datetime(2023, 12, 31), api_key=api_key)
aapl_df

# %% [markdown]
# # FRED
#
# https://fred.stlouisfed.org/
#
# 10-Year Breakeven Inflation Rate (T10YIE)
#
# https://fred.stlouisfed.org/series/T10YIE

# %%
ty_inflation_df = web.DataReader('T10YIE', 'fred', start='2000-01-01', end='2025-09-01')

# %%
ty_inflation_df.plot()
# Out:
# <Axes: xlabel='DATE'>

# %% [markdown]
# ### Yahoo Finance yfinance (unofficial API)

# %%
#pip install yfinance

# %%
import yfinance as yf

# %%
apple= yf.download("AAPL",start='2020-01-01',end='2021-01-01')
# Out:
# C:\Users\rafa_\AppData\Local\Temp\ipykernel_9492\3433078983.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   apple= yf.download("AAPL",start='2020-01-01',end='2021-01-01')
# [*********************100%***********************]  1 of 1 completed

# %%
apple
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2020-01-02   72.538506   72.598884   71.292296   71.545882  135480400
# 2020-01-03   71.833298   72.594063   71.608692   71.765674  146322800
# 2020-01-06   72.405670   72.444313   70.703005   70.954181  118387200
# 2020-01-07   72.065155   72.671348   71.845377   72.415345  108872000
# 2020-01-08   73.224403   73.526295   71.768079   71.768079  132079200
# ...                ...         ...         ...         ...        ...
# 2020-12-24  128.591019  130.042874  127.743299  127.957667   54930100
# 2020-12-28  133.190216  133.823568  130.091628  130.559349  124486200
# 2020-12-29  131.416779  135.236409  130.900350  134.515365  121047300
# 2020-12-30  130.296234  132.508117  129.984420  132.108611   96452100
# 2020-12-31  129.292633  131.290148  128.347468  130.647043   99116600
#
# [253 rows x 5 columns]

# %% [markdown]
# ### General Information

# %%
apple_ticker = yf.Ticker('AAPL')

# %%
apple_ticker.financials
# Out:
# yfinance.Ticker object <AAPL>

# %%
apple_ticker.actions
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-066d1906dd31> in <module>
# ----> 1 apple_ticker.actions
#
# ~\miniconda3\lib\site-packages\yfinance\ticker.py in actions(self)
#     137     @property
#     138     def actions(self):
# --> 139         return self.get_actions()
#     140
#     141     @property
#
# ~\miniconda3\lib\site-packages\yfinance\base.py in get_actions(self, proxy)
#     811     def get_actions(self, proxy=None):
#     812         if self._history is None:
# --> 813             self.history(period="max", proxy=proxy)
#     814         if self._history is not None and "Dividends" in self._history and "Stock Splits" in self._history:
#     815             actions = self._history[["Dividends", "Stock Splits"]]
#
# ...

# %%
apple_ticker.dividends
